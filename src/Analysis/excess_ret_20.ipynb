# %%
import yfinance as yf
import pandas as pd
import polars as pl
import os
import re
import urllib.parse
from datetime import datetime
import matplotlib.pyplot as plt
import statsmodels.api as sm
import math 
import pyarrow
import numpy as np

# %%
COMPANY_NAME_LIST = ['Apple%2520Inc.%2520(AAPL)%2520(CIK%25200000320193)', 'MICROSOFT%2520CORP%2520(MSFT)%2520(CIK%25200000789019)', 
                     'BigCommerce%2520Holdings%252C%2520Inc.%2520(BIGC)%2520(CIK%25200001626450)', 'ROKU%252C%2520INC%2520(ROKU)%2520(CIK%25200001428439)', 
                     'JPMORGAN%2520CHASE%2520%2526%2520CO%2520(JPM%252C%2520AMJ%252C%2520AMJB%252C%2520JPM)%2520(CIK%25200000019617)', 'VISA%2520INC.%2520(V)%2520(CIK%25200001403161)', 
                     'Block%252C%2520Inc.%2520(SQ%252C%2520BSQKZ)%2520(CIK%25200001512673)', 'Robinhood%2520Markets%252C%2520Inc.%2520(HOOD)%2520(CIK%25200001783879)', 
                     'JOHNSON%252C%252C%2520JOHNSON%2520(JNJ)%2520(CIK%25200000200406)', 'PFIZER%2520INC%2520(PFE)%2520(CIK%25200000078003)', 
                     'Moderna%252C%2520Inc.%2520(MRNA)%2520(CIK%25200001682852)', 'Teladoc%2520Health%252C%2520Inc.%2520(TDOC)%2520(CIK%25200001477449)', 
                     'EXXON%2520MOBIL%2520CORP%2520(XOM)%2520(CIK%25200000034088)', 'CHEVRON%2520CORP%2520(CVX)%2520(CIK%25200000093410)', 
                     'FIRST%2520SOLAR%252C%2520INC.%2520(FSLR)%2520(CIK%25200001274494)', 'PLUG%2520POWER%2520INC%2520(PLUG)%2520(CIK%25200001093691)', 
                     'GENERAL%252CELECTRIC%2520CO%2520(GE)%2520(CIK%25200000040545)', '3M%2520CO%2520(MMM)%2520(CIK%25200000066740)', 
                     'CATERPILLAR%2520INC%2520(CAT)%2520(CIK%25200000018230)', 'FASTENAL%2520CO%2520(FAST)%2520(CIK%25200000815556)']

# %% [markdown]
# Collect scores from hard memory

# %%
df_dict_scores = {}
regex = r"\\([^\\]+)_full_doc_sen_score_df\.parquet$"

for root, dirs, files in os.walk(r'Parsim-sec\src\Analysis\data\20_com_full_doc'):
    for file in files:
            
            file_path = os.path.join(root, file)
            ticker = re.search(regex, file_path).group(1)
            
            df = pl.read_parquet(file_path)

            df_dict_scores[ticker] = df

# %%
df = df_dict_scores["GE"]
tic_sym = "GE"
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = df_dict_scores["GE"]
#       2 tic_sym = "GE"
#       3 df
#
# KeyError: 'GE'

# %% [markdown]
# This is support func to find end prices and their dates. It takes as an arguments starting index, which is the nuber of row of hist dataframe and this hist dataframe itself. Hist dataframe contain daily OHLC data for particular ticker (company).
#
# It also cheks wether index of end price is in hist, meaning that if this particular report was released very resently (less then 8 trading days ago) it will append none values for end prices out of range of hist df instead of raising an error.
#
# It returns lists of end prices and corresponding dates (none values for prices and their dates, if they are out of range of hist df).

# %%
def find_end_price(start_index, hist):
    end_price_list = []
    end_price_date_list = []
    
    for x in range(2, 8):
        idx = start_index + x
        if idx < len(hist):
            end_price_list.append(hist.iloc[idx]['Open'])
            end_price_date_list.append(hist.index[idx])
        else:
            end_price_list.append(None)
            end_price_date_list.append(None)
    return end_price_list, end_price_date_list

# %% [markdown]
# This is support func to calc the regular returns. It takes start price and end_price_list as an arguments. It checks whether value in end price list is none and if it is, it appends none in returns list, instead of raising an error. So we are shure that all end price lists are of the same length, but for those prices that are not found in historical data we have none values for returns.

# %%
def regular_returns(start_price, end_price_list):
    retuns = []
    for end_price in end_price_list:
        if end_price is None:
            retuns.append(None)
        else:
            ret = (end_price - start_price) / start_price * 100
            retuns.append(ret)
    return retuns

# %% [markdown]
# This is the support func that calc SnP500 returns. It takes_start date and end_price_date_list as and arguments and then calculate returns for this timeframes. This func also checks whether value of end_price_date_list is none (meaning that it is not found in historical data), and if it is, func will append none instead of raising an error.
#
# Now we are shure that list of snp_returns will be of equal length for all report release dates and all time frames, but for those returns that cannot be calculates due to non existent end prices we will have nones

# %%
def snp_500_return(start_date, end_price_date_list, snp_price):

    snp_returns = []

    for end_date in end_price_date_list:
        if end_date is None:
            snp_returns.append(None)

        else: 
            start_index = snp_price.index.get_loc(start_date)
            start_price = snp_price.iloc[start_index]['Open']
    
            end_index = snp_price.index.get_loc(end_date)
            end_price = snp_price.iloc[end_index]['Open']
    
            ret = (end_price - start_price) / start_price * 100
            
            snp_returns.append(ret)

    return snp_returns

# %% [markdown]
# This is suppurt function that retrive the end quarter price. It take as an argument hist - historical price dataframe, date_str - the date of release of this particular report, df - company dataframe, with cols named with dates of releases of corresponding reports.
#
# It takes the release date for current report and checks whether it is the last date in time series or not. If it is (this mean that we are are realy close to the end of hist df) we consider the end of hist df as the end of quarter. if it is not, we take next date in company df (which is the date of releas of the next quarterly report) and see its open price, this is pricisely the end of the quarter.

# %%
def find_end_quarter(hist, date_str, df):

    col_names = df.columns
    current_date_index = col_names.index(date_str)

    if current_date_index < len(col_names) - 1:

        next_date = col_names[current_date_index + 1]

        next_date_time_stemp = pd.Timestamp(next_date, tz='America/New_York')

        while next_date_time_stemp not in hist.index:

            next_date_time_stemp += pd.Timedelta(days=1)
    
        end_quarter_index = hist.index.get_loc(next_date_time_stemp)
        end_quarter_price = hist.iloc[end_quarter_index]['Open']
        end_quarter_date = hist.index[end_quarter_index]
        
        current_date_time_stemp = pd.Timestamp(date_str, tz='America/New_York')

        if current_date_time_stemp in hist.index:

            start_quarter_index = hist.index.get_loc(current_date_time_stemp)
        else:
            print('cannot find in index')
            print(f'current_date_time_stemp: {current_date_time_stemp}')
            first_date = hist.index[0]
            print(f'firts date: {first_date}')

        quarter_length = end_quarter_index - start_quarter_index

    else:
        end_quarter_price = None
        end_quarter_date = None
        quarter_length = None
    

    return end_quarter_price, end_quarter_date, quarter_length

# %% [markdown]
# This is a func that takes as an input a key-value pair from df_dict_scores and calculate 2-days, 3-days, 4-days, 5-days, 6-days, 7-days and full quarter excess returns for it (S&P500 is the benchmark). It stores the result as a polars df with dates of starting of the period as col names and corresponding returns as col values (seven in each: starting from 2-days down to 7-days and full quarter) -

# %%
company_ticker = yf.Ticker(tic_sym)
hist = company_ticker.history(period="6y")
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2018-05-07 00:00:00-04:00   64.170638   64.580529   63.760747   64.079552
# 2018-05-08 00:00:00-04:00   64.580511   65.992357   64.170620   64.990402
# 2018-05-09 00:00:00-04:00   65.354768   66.857701   65.127049   66.584442
# 2018-05-10 00:00:00-04:00   67.222034   67.222034   66.037907   66.903229
# 2018-05-11 00:00:00-04:00   67.130935   67.267568   66.128980   66.493332
# ...                               ...         ...         ...         ...
# 2024-04-30 00:00:00-04:00  163.559998  166.259995  161.580002  161.820007
# 2024-05-01 00:00:00-04:00  162.570007  163.300003  158.820007  159.699997
# 2024-05-02 00:00:00-04:00  161.389999  162.820007  159.419998  162.639999
# 2024-05-03 00:00:00-04:00  165.300003  165.300003  162.009995  164.110001
# 2024-05-06 00:00:00-04:00  165.119995  167.979996  165.029999  167.970001
#
#                              Volume  Dividends  Stock Splits
# Date
# 2018-05-07 00:00:00-04:00   6858410        0.0           0.0
# 2018-05-08 00:00:00-04:00  12381195        0.0           0.0
# 2018-05-09 00:00:00-04:00  10614202        0.0           0.0
# 2018-05-10 00:00:00-04:00   7820843        0.0           0.0
# 2018-05-11 00:00:00-04:00   5970052        0.0           0.0
# ...                             ...        ...           ...
# 2024-04-30 00:00:00-04:00   6723600        0.0           0.0
# 2024-05-01 00:00:00-04:00   4775800        0.0           0.0
# 2024-05-02 00:00:00-04:00   5030400        0.0           0.0
# 2024-05-03 00:00:00-04:00   3968600        0.0           0.0
# 2024-05-06 00:00:00-04:00   4830300        0.0           0.0
#
# [1510 rows x 7 columns]

# %%
def computing_returns(tic_sym, df):

    company_ticker = yf.Ticker(tic_sym)
    hist = company_ticker.history(period="6y")

    snp500_ticker = yf.Ticker("^GSPC")
    snp_price = snp500_ticker.history(period="6y", auto_adjust=True)
    
    returns = {}

    for date_str in df.columns:

        start_date = pd.Timestamp(date_str, tz='America/New_York')
        
        while start_date not in hist.index:

            start_date += pd.Timedelta(days=1)
        

        start_index = hist.index.get_loc(start_date)

        start_price = hist.iloc[start_index]['Open']

        end_price_list, end_price_date_list = find_end_price(start_index, hist)
        
        if None not in end_price_list:
            end_quarter_price, end_quarter_date, length_of_quarter = find_end_quarter(hist, date_str, df)
            
        else:
            end_quarter_price = None
            end_quarter_date = None

        
        end_price_list.append(end_quarter_price)
        end_price_date_list.append(end_quarter_date)
        
        reg_returns = regular_returns(start_price, end_price_list)
        snp_returns = snp_500_return(start_date, end_price_date_list, snp_price)
        
        excess_returns = [a - b if a is not None and b is not None else None for a, b in zip(reg_returns, snp_returns)]
        
        #normalization: divide returns for each time frame by number of trading days (2-days returns/2, 3-days returns/3, ful quarter returns/length_of_quarter)
        timeframe_length = [2, 3, 4, 5, 6, 7, length_of_quarter]

        normalized_excess_returns = [x / y if x is not None and y is not None else None for x, y in zip(excess_returns, timeframe_length)]

        returns[date_str] = normalized_excess_returns

    returns = pl.DataFrame(returns)
    
    return returns

# %%
computing_returns(tic_sym, df)
# Out:
# shape: (7, 21)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ 2019-04-3 ┆ 2019-07-3 ┆ 2019-10-3 ┆ 2020-02-2 ┆ … ┆ 2023-07-2 ┆ 2023-10-2 ┆ 2024-02-0 ┆ 2024-04- │
# │ 0         ┆ 1         ┆ 0         ┆ 4         ┆   ┆ 5         ┆ 4         ┆ 2         ┆ 23       │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ f64       ┆ f64       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ -0.135994 ┆ -2.286279 ┆ 1.353142  ┆ 0.438005  ┆ … ┆ -0.009876 ┆ 1.030062  ┆ 0.483866  ┆ 0.171553 │
# │ 0.318082  ┆ -1.699236 ┆ 1.751244  ┆ -1.054996 ┆ … ┆ 0.222579  ┆ 0.108764  ┆ 0.398735  ┆ 0.301743 │
# │ 0.264892  ┆ -1.154535 ┆ 2.576425  ┆ -1.106406 ┆ … ┆ -0.175717 ┆ -0.225727 ┆ 0.19215   ┆ 0.394966 │
# │ 0.379224  ┆ -1.408712 ┆ 2.119088  ┆ 0.918282  ┆ … ┆ -0.24528  ┆ 0.027005  ┆ 0.17023   ┆ 0.428098 │
# │ 0.082072  ┆ -1.273048 ┆ 1.99026   ┆ 0.197163  ┆ … ┆ -0.207122 ┆ -0.276899 ┆ 0.130259  ┆ 0.499944 │
# │ 0.208395  ┆ -1.306744 ┆ 1.922946  ┆ 0.159189  ┆ … ┆ -0.14207  ┆ -0.388662 ┆ 0.313372  ┆ 0.264078 │
# │ 0.040864  ┆ -0.152569 ┆ 0.160232  ┆ -0.703804 ┆ … ┆ 0.063846  ┆ 0.086811  ┆ 0.799817  ┆ null     │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df = df_dict_scores["ROKU"]
tic_sym = "ROKU"
df
# Out:
# shape: (5, 21)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ 2019-05-1 ┆ 2019-08-0 ┆ 2019-11-0 ┆ 2020-03-0 ┆ … ┆ 2023-07-2 ┆ 2023-11-0 ┆ 2024-02-1 ┆ 2024-04- │
# │ 0         ┆ 9         ┆ 8         ┆ 2         ┆   ┆ 8         ┆ 2         ┆ 6         ┆ 26       │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ f64       ┆ f64       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ -27.29522 ┆ -26.76927 ┆ -27.19424 ┆ -28.55945 ┆ … ┆ -38.18670 ┆ -38.39313 ┆ -38.26779 ┆ -39.0346 │
# │ 6         ┆ 6         ┆ 9         ┆ 7         ┆   ┆ 8         ┆ 2         ┆ 7         ┆ 12       │
# │ -164.0    ┆ -160.0    ┆ -162.0    ┆ -173.0    ┆ … ┆ -197.0    ┆ -198.0    ┆ -198.0    ┆ -200.0   │
# │ -0.422897 ┆ -0.411494 ┆ -0.415051 ┆ -0.371429 ┆ … ┆ -0.46217  ┆ -0.477837 ┆ -0.399584 ┆ -0.46365 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 2        │
# │ 0.466667  ┆ 0.462373  ┆ 0.469699  ┆ 0.489944  ┆ … ┆ 0.398859  ┆ 0.387704  ┆ 0.470352  ┆ 0.404057 │
# │ 34909.0   ┆ 36320.0   ┆ 37040.0   ┆ 57876.0   ┆ … ┆ 41641.0   ┆ 42433.0   ┆ 57998.0   ┆ 41937.0  │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# This is the general loop, that takes each key-value pair from df_dict_scores, applies computing_returns() to it, then verticaly stackes the result with orig df and stores it in the new dict

# %%
dict_for_anal = {}
row_names = pl.Series("row_names", ["weighted scores", "raw scores", "lm scores", "harvard scores", "doc length", "2_day_reterns","3_day_reterns", "4_day_reterns", "5_day_reterns", "6_day_reterns", "7_day_reterns", "full_quarter_returns"])

for tic_sym, df in df_dict_scores.items():
    print(tic_sym)

    returns_df = computing_returns(tic_sym, df)
    
    stacked_df = df.vstack(returns_df)
    stacked_df_with_indx = stacked_df.hstack([row_names])
    
    dict_for_anal[tic_sym] = stacked_df_with_indx
# Out:
# AAPL
# BIGC
# CAT
# CVX
# FAST
# FSLR
# GE
# HOOD
# JNJ
# JPM
# MMM
# MRNA
# MSFT
# PFE
# PLUG
# ROKU
# SQ
# TDOC
# V
# XOM

# %%
dict_for_anal["XOM"]
# Out:
# shape: (12, 21)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ 2019-05-0 ┆ 2019-08-0 ┆ 2019-11-0 ┆ 2020-02-2 ┆ … ┆ 2023-08-0 ┆ 2023-10-3 ┆ 2024-02-2 ┆ row_name │
# │ 2         ┆ 7         ┆ 6         ┆ 6         ┆   ┆ 1         ┆ 1         ┆ 8         ┆ s        │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ f64       ┆ f64       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ -5.624371 ┆ -5.774065 ┆ -6.142186 ┆ -15.57336 ┆ … ┆ -3.472974 ┆ -4.291548 ┆ -18.63346 ┆ weighted │
# │           ┆           ┆           ┆ 9         ┆   ┆           ┆           ┆ 3         ┆ scores   │
# │ -34.0     ┆ -34.0     ┆ -38.0     ┆ -96.0     ┆ … ┆ -22.0     ┆ -23.0     ┆ -110.0    ┆ raw      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ scores   │
# │ -0.253456 ┆ -0.263158 ┆ -0.261084 ┆ -0.091067 ┆ … ┆ -0.25     ┆ -0.265823 ┆ -0.075515 ┆ lm       │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ scores   │
# │ 0.532777  ┆ 0.5225    ┆ 0.530864  ┆ 0.553063  ┆ … ┆ 0.438776  ┆ 0.434084  ┆ 0.536935  ┆ harvard  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ scores   │
# │ 5714.0    ┆ 5888.0    ┆ 5988.0    ┆ 38731.0   ┆ … ┆ 5787.0    ┆ 6988.0    ┆ 40099.0   ┆ doc      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ length   │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ -0.191677 ┆ -0.09593  ┆ -0.669581 ┆ 0.070892  ┆ … ┆ 0.698443  ┆ -0.543068 ┆ -0.199369 ┆ 4_day_re │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ terns    │
# │ -0.066573 ┆ -0.228677 ┆ -0.85038  ┆ -0.250894 ┆ … ┆ 0.182757  ┆ -1.144647 ┆ 0.250449  ┆ 5_day_re │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ terns    │
# │ 0.07565   ┆ -0.299875 ┆ -0.781364 ┆ -0.921066 ┆ … ┆ 0.555494  ┆ -1.143245 ┆ 0.125426  ┆ 6_day_re │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ terns    │
# │ 0.079014  ┆ -0.283439 ┆ -0.779326 ┆ -0.650465 ┆ … ┆ 0.718785  ┆ -1.012154 ┆ 0.103216  ┆ 7_day_re │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ terns    │
# │ -0.112834 ┆ -0.033891 ┆ -0.334794 ┆ -0.193018 ┆ … ┆ 0.131686  ┆ -0.255498 ┆ null      ┆ full_qua │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ rter_ret │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ urns     │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# Lets start the analisys. The general question is: how well sentiment scores and weighted scores can explain returns?

# %% [markdown]
# Lets see them on the graph:

# %%
#for company_name, scores in dict_for_anal.items():
#   
#    df_for_plt = scores.select(pl.exclude("row_names"))
#
#    dates = [datetime.strptime(date, "%Y-%m-%d") for date in df_for_plt.columns]
#   
#    plt.figure(figsize=(10, 6))
#    row_indices_to_plot = [0, 1, 4, -1]
#
#    for idx in row_indices_to_plot:
#        row = df_for_plt.row(idx, named=True)  
#        plt.plot(dates, list(row.values()), label=scores.row(idx)[-1])
#
#    plt.title(company_name)
#    plt.xlabel("Date")
#    plt.ylabel("Values")
#    plt.legend()
#    plt.xticks(rotation=45)
#    plt.tight_layout()
#    plt.show()

# %% [markdown]
# At first glance some time series exhibits at least piecewise dependence.
#
# Next step is to regress each return on weighted, raw scores and polarity scores from Loughran-McDonald and Harvard dictionaries.
#
# And also we can see that in cases of 10-K reports which are typicly much longer we can see strong pattern in raw scores which is smoothed in weighted scores. But still this pattern could be recognized. This can be interpreted as 10-K can contain more information about future prices

# %% [markdown]
# This func takes as input key-value pair (company name and dataframe with sentiment scores and returns), regress each retern (2_days, 3_days, etc) on weightes sentiment score ans raw sentiment score. Then it collects the slopes (beta-coefficient) of returns regressed on raw score and on weighted score in the separate polars series (in the loop they will be staked in dataframe)

# %%
def add_quarter_dummy(company_df_pd):
    
    dates = pd.to_datetime(company_df_pd.columns)
    date_series = pd.Series(dates.quarter, index=dates)

    dummies = pd.get_dummies(date_series, prefix="Q")
    dummies.index = dummies.index.strftime('%Y-%m-%d')

    dummies = dummies.drop(columns=["Q_4"])
    
    dummies = dummies.transpose()
    df_wit_dum = pd.concat([company_df_pd, dummies])

    df_wit_dum = df_wit_dum.transpose()

    for col in df_wit_dum.columns:
        df_wit_dum[col] = pd.to_numeric(df_wit_dum[col])

    boolean_cols = ['Q_1', 'Q_2', 'Q_3']
    df_wit_dum[boolean_cols] = df_wit_dum[boolean_cols].astype(int)

    return df_wit_dum

# %%
def fit_regression(y, x):

    x = sm.add_constant(x)
    model = sm.OLS(y, x, missing='drop').fit()
    
    slope = model.params.iloc[1]
    print(model.summary())
    
    return slope

# %%
def regression_slopes(df_wit_dum, X_names, company_name="total_df"):

    # x in range(0, 4) represents set of independent variables; 4th column represents control variable for document length; -3, -2, -1 columns represent dummy variables for quarters
    X = [df_wit_dum.iloc[:, [x, 4, -3, -2, -1]] for x in range(0, 4)]

    Y = [df_wit_dum.iloc[:, [y]] for y in range(5, 12)]

    slopes_dict = {}

    for i, x in enumerate(X):

        name_of_score = X_names[i][0].split()[0]
        slopes_name = f'{name_of_score}_slopes'
        
        slopes = []
        for y in Y:
            slope = fit_regression(y, x)
            slopes.append(slope)

        slopes_dict[slopes_name] = pl.Series(company_name, slopes)
    
    return slopes_dict

# %% [markdown]
# This is the general loop that takes dict_for_anal() whith scores and returns and for each company in the dict it calculates two series: first one contain regression slopes for weighted scores and second one for raw scores. Serieses stacked in the separete dataframes (for raw and for weighted scores)

# %%
def compute_all_slopes(dict_for_anal):

    slopes_df_dict = {
        "weighted_slopes_df" : pl.DataFrame(),
        "raw_slopes_df" : pl.DataFrame(),
        "lm_slopes_df" : pl.DataFrame(),
        "harvard_slopes_df" : pl.DataFrame()
    }
    
    for company_name, company_df in dict_for_anal.items(): 

        X_names = [company_df.select(pl.col("row_names")).row(x) for x in range(0, 4)]

        company_df_woi = company_df.select(pl.exclude("row_names"))

        company_df_woi = company_df_woi.to_pandas()

        df_wit_dum = add_quarter_dummy(company_df_woi)

        slopes_dict = regression_slopes(df_wit_dum, X_names, company_name)

        for x in X_names:
            
            name_of_score = x[0].split()[0]
            slopes_name = f'{name_of_score}_slopes'
            
            df_name = f"{name_of_score}_slopes_df"
            
            slopes_df_dict[df_name] = slopes_df_dict[df_name].hstack([slopes_dict[slopes_name]])

    return slopes_df_dict

# %%
slopes_df_dict = compute_all_slopes(dict_for_anal)

# %% [markdown]
# As an output from previous functions we have dataframes with regression slopes of different returns on raw, weighted scores and Loughran-McDonald and Harvard dictionaries. Each col of these dfs contain regression slopes for particular company. First row contain slope for 2_days return, second row contain slope for 3_days return, etc.  I have decided to check what is the proportion of positive regression slopes for each return timeframe (2_days, 3_days, etc). For that purpose i will transpose each of these dfs, apply condition > 0, then verticaly sum boolean values and obtain the prorortion of positive slopes for each time frame.

# %%
def calc_efficiency_metrics(slopes_df):

    df_tranposed = slopes_df.transpose()

    res = df_tranposed.select(pl.all() > 0).sum()
    total_num_of_slopes = slopes_df.shape[1]

    positive_slopes = [res.select(pl.col(res.columns[x]).gather(0)).item() for x in range(slopes_df.shape[0])]

    for counter, x in enumerate(positive_slopes):
        print(f'Prorortion of positive {counter + 2}_day returns: {x/total_num_of_slopes}')

# %% [markdown]
# This loop apply calc_efficiency_metrics function to each item of slopes_df_dict where each item is a dataframe which regression slopes for each regressor.

# %%
for key, slopes_df in slopes_df_dict.items():
    print("\n")
    print(f'Metrics for: {key}')
    calc_efficiency_metrics(slopes_df)
# Out:
# Metrics for: weighted_slopes_df
# Prorortion of positive 2_day returns: 0.45
# Prorortion of positive 3_day returns: 0.45
# Prorortion of positive 4_day returns: 0.55
# Prorortion of positive 5_day returns: 0.45
# Prorortion of positive 6_day returns: 0.4
# Prorortion of positive 7_day returns: 0.45
# Prorortion of positive 8_day returns: 0.7
#
#
# Metrics for: raw_slopes_df
# Prorortion of positive 2_day returns: 0.45
# Prorortion of positive 3_day returns: 0.45
# Prorortion of positive 4_day returns: 0.55
# Prorortion of positive 5_day returns: 0.6
# Prorortion of positive 6_day returns: 0.5
# Prorortion of positive 7_day returns: 0.65
# Prorortion of positive 8_day returns: 0.65
#
#
# Metrics for: lm_slopes_df
# Prorortion of positive 2_day returns: 0.5
# Prorortion of positive 3_day returns: 0.4
# Prorortion of positive 4_day returns: 0.45
# Prorortion of positive 5_day returns: 0.5
# Prorortion of positive 6_day returns: 0.4
# Prorortion of positive 7_day returns: 0.45
# Prorortion of positive 8_day returns: 0.5
#
#
# Metrics for: harvard_slopes_df
# Prorortion of positive 2_day returns: 0.55
# Prorortion of positive 3_day returns: 0.5
# Prorortion of positive 4_day returns: 0.45
# Prorortion of positive 5_day returns: 0.4
# Prorortion of positive 6_day returns: 0.4
# Prorortion of positive 7_day returns: 0.3
# Prorortion of positive 8_day returns: 0.5

# %% [markdown]
# Positive slopes means that sentiment scores and returns mooves in the same direction (hense, they are working as predictors of stock price movement). As the result of this preliminary analisis we can say that sentiment scores of quarterly reports are not very good predictors of stock movments. Positive proportion of this slopes are close to 0.5, which means that on average in our sample there are 50/50 chance that scores and returns are mooving in the same direction.
#
# As we can see that, despite visual conclusion that weighted scores are more "smooth", they barely outperform raw scores, but at least they are not worse, meaning that at each time frame (except 5_days) the proportion of positive regression slopes of weighted scores => proportion of positive regression slopes of raw scores.

# %% [markdown]
# This func stackes all data in one df, and calculate the single slope for each time frame

# %%
def compute_signl_slope(dict_for_anal):

    df_list = []
    
    for company_name in dict_for_anal:


        X_names = [dict_for_anal[company_name].select(pl.col("row_names")).row(x) for x in range(0, 4)] 
    
        company_df_woi = dict_for_anal[company_name].select(pl.exclude("row_names"))
        company_df_pd = company_df_woi.to_pandas(use_pyarrow_extension_array=True)

        df_wit_dum = add_quarter_dummy(company_df_pd)

        df_list.append(df_wit_dum)
        

    total_df = pd.concat(df_list, ignore_index=True)
    
    slopes_dict = regression_slopes(total_df, X_names)

    return slopes_dict

# %%
slopes_dict = compute_signl_slope(dict_for_anal)
print(slopes_dict)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      5   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9166
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.470
# Time:                        13:01:30   Log-Likelihood:                -1013.0
# No. Observations:                 392   AIC:                             2038.
# Df Residuals:                     386   BIC:                             2062.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1518      0.405      0.374      0.708      -0.645       0.949
# 0             -0.0263      0.018     -1.447      0.149      -0.062       0.009
# 4          -2.558e-05   1.55e-05     -1.655      0.099    -5.6e-05     4.8e-06
# Q_1            0.6795      0.515      1.319      0.188      -0.333       1.692
# Q_2           -0.2463      0.462     -0.533      0.594      -1.154       0.662
# Q_3            0.1503      0.465      0.323      0.747      -0.763       1.064
# ==============================================================================
# Omnibus:                       93.092   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2011.834
# Skew:                          -0.343   Prob(JB):                         0.00
# Kurtosis:                      14.077   Cond. No.                     1.80e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      6   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.8305
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.529
# Time:                        13:01:30   Log-Likelihood:                -895.69
# No. Observations:                 392   AIC:                             1803.
# Df Residuals:                     386   BIC:                             1827.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3554      0.300      1.183      0.238      -0.235       0.946
# 0             -0.0008      0.013     -0.059      0.953      -0.027       0.026
# 4          -9.753e-06   1.15e-05     -0.851      0.395   -3.23e-05    1.28e-05
# Q_1            0.2552      0.382      0.668      0.504      -0.496       1.006
# Q_2           -0.4170      0.342     -1.218      0.224      -1.090       0.256
# Q_3           -0.0080      0.345     -0.023      0.982      -0.685       0.669
# ==============================================================================
# Omnibus:                       79.224   Durbin-Watson:                   2.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1429.123
# Skew:                           0.151   Prob(JB):                    4.68e-311
# Kurtosis:                      12.349   Cond. No.                     1.80e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      7   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9915
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.423
# Time:                        13:01:30   Log-Likelihood:                -809.92
# No. Observations:                 392   AIC:                             1632.
# Df Residuals:                     386   BIC:                             1656.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3638      0.241      1.507      0.133      -0.111       0.838
# 0              0.0083      0.011      0.767      0.444      -0.013       0.030
# 4          -1.227e-06    9.2e-06     -0.133      0.894   -1.93e-05    1.69e-05
# Q_1            0.0594      0.307      0.194      0.847      -0.544       0.663
# Q_2           -0.4167      0.275     -1.515      0.131      -0.958       0.124
# Q_3           -0.1333      0.277     -0.482      0.630      -0.678       0.411
# ==============================================================================
# Omnibus:                       85.647   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              723.070
# Skew:                           0.644   Prob(JB):                    9.71e-158
# Kurtosis:                       9.528   Cond. No.                     1.80e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      8   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.7234
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.606
# Time:                        13:01:30   Log-Likelihood:                -739.28
# No. Observations:                 392   AIC:                             1491.
# Df Residuals:                     386   BIC:                             1514.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2191      0.202      1.087      0.278      -0.177       0.615
# 0              0.0052      0.009      0.572      0.568      -0.013       0.023
# 4          -1.617e-06   7.69e-06     -0.210      0.833   -1.67e-05    1.35e-05
# Q_1            0.1024      0.256      0.400      0.690      -0.401       0.606
# Q_2           -0.2809      0.230     -1.223      0.222      -0.733       0.171
# Q_3           -0.1207      0.231     -0.522      0.602      -0.575       0.334
# ==============================================================================
# Omnibus:                       54.989   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              374.768
# Skew:                           0.307   Prob(JB):                     4.17e-82
# Kurtosis:                       7.751   Cond. No.                     1.80e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      9   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9172
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.470
# Time:                        13:01:30   Log-Likelihood:                -676.53
# No. Observations:                 392   AIC:                             1365.
# Df Residuals:                     386   BIC:                             1389.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0938      0.172      0.546      0.585      -0.244       0.432
# 0              0.0091      0.008      1.175      0.241      -0.006       0.024
# 4           3.253e-06   6.55e-06      0.497      0.620   -9.62e-06    1.61e-05
# Q_1            0.0754      0.218      0.345      0.730      -0.354       0.505
# Q_2           -0.2516      0.196     -1.285      0.199      -0.637       0.133
# Q_3           -0.0431      0.197     -0.219      0.827      -0.430       0.344
# ==============================================================================
# Omnibus:                       43.504   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              258.543
# Skew:                           0.141   Prob(JB):                     7.21e-57
# Kurtosis:                       6.969   Cond. No.                     1.80e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     10   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.4138
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.839
# Time:                        13:01:30   Log-Likelihood:                -642.49
# No. Observations:                 390   AIC:                             1297.
# Df Residuals:                     384   BIC:                             1321.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0358      0.159      0.225      0.822      -0.277       0.348
# 0              0.0082      0.007      1.151      0.250      -0.006       0.022
# 4           5.298e-06   6.06e-06      0.875      0.382   -6.61e-06    1.72e-05
# Q_1            0.0029      0.202      0.014      0.988      -0.394       0.400
# Q_2           -0.1111      0.182     -0.611      0.542      -0.469       0.247
# Q_3           -0.0873      0.182     -0.480      0.632      -0.445       0.271
# ==============================================================================
# Omnibus:                       89.596   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              578.355
# Skew:                           0.788   Prob(JB):                    2.58e-126
# Kurtosis:                       8.754   Cond. No.                     1.80e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     11   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     1.673
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.140
# Time:                        13:01:30   Log-Likelihood:                -184.05
# No. Observations:                 372   AIC:                             380.1
# Df Residuals:                     366   BIC:                             403.6
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0147      0.051      0.288      0.773      -0.085       0.115
# 0              0.0044      0.002      1.940      0.053   -5.93e-05       0.009
# 4            3.41e-06   1.94e-06      1.758      0.080   -4.03e-07    7.22e-06
# Q_1           -0.0772      0.066     -1.170      0.243      -0.207       0.053
# Q_2            0.0628      0.058      1.082      0.280      -0.051       0.177
# Q_3           -0.0443      0.058     -0.770      0.442      -0.157       0.069
# ==============================================================================
# Omnibus:                      173.786   Durbin-Watson:                   1.922
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1431.410
# Skew:                           1.775   Prob(JB):                    1.49e-311
# Kurtosis:                      11.930   Cond. No.                     1.72e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      5   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     1.354
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.241
# Time:                        13:01:30   Log-Likelihood:                -1012.0
# No. Observations:                 392   AIC:                             2036.
# Df Residuals:                     386   BIC:                             2060.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1083      0.418     -0.259      0.796      -0.931       0.714
# 1             -0.0081      0.004     -2.066      0.040      -0.016      -0.000
# 4          -2.959e-05   1.38e-05     -2.147      0.032   -5.67e-05   -2.49e-06
# Q_1            0.6987      0.512      1.364      0.173      -0.309       1.706
# Q_2           -0.2314      0.461     -0.502      0.616      -1.137       0.674
# Q_3            0.1736      0.464      0.374      0.708      -0.738       1.085
# ==============================================================================
# Omnibus:                       93.416   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1990.127
# Skew:                          -0.357   Prob(JB):                         0.00
# Kurtosis:                      14.015   Cond. No.                     1.82e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.82e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      6   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9379
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.456
# Time:                        13:01:30   Log-Likelihood:                -895.42
# No. Observations:                 392   AIC:                             1803.
# Df Residuals:                     386   BIC:                             1827.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2944      0.311      0.947      0.344      -0.317       0.906
# 1             -0.0021      0.003     -0.731      0.465      -0.008       0.004
# 4          -1.523e-05   1.02e-05     -1.488      0.138   -3.54e-05     4.9e-06
# Q_1            0.2836      0.381      0.745      0.457      -0.465       1.032
# Q_2           -0.4161      0.342     -1.216      0.225      -1.089       0.256
# Q_3            0.0018      0.344      0.005      0.996      -0.676       0.679
# ==============================================================================
# Omnibus:                       79.085   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1416.403
# Skew:                           0.154   Prob(JB):                    2.70e-308
# Kurtosis:                      12.307   Cond. No.                     1.82e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.82e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      7   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.8731
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.499
# Time:                        13:01:30   Log-Likelihood:                -810.22
# No. Observations:                 392   AIC:                             1632.
# Df Residuals:                     386   BIC:                             1656.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3706      0.250      1.482      0.139      -0.121       0.862
# 1             -0.0001      0.002     -0.049      0.961      -0.005       0.004
# 4          -7.552e-06   8.24e-06     -0.917      0.360   -2.38e-05    8.65e-06
# Q_1            0.0928      0.306      0.303      0.762      -0.509       0.695
# Q_2           -0.4208      0.275     -1.529      0.127      -0.962       0.120
# Q_3           -0.1279      0.277     -0.461      0.645      -0.673       0.417
# ==============================================================================
# Omnibus:                       87.259   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              745.524
# Skew:                           0.659   Prob(JB):                    1.29e-162
# Kurtosis:                       9.626   Cond. No.                     1.82e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.82e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      8   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.6670
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.649
# Time:                        13:01:30   Log-Likelihood:                -739.42
# No. Observations:                 392   AIC:                             1491.
# Df Residuals:                     386   BIC:                             1515.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2134      0.209      1.022      0.307      -0.197       0.624
# 1             -0.0004      0.002     -0.217      0.828      -0.004       0.003
# 4          -6.561e-06   6.88e-06     -0.954      0.341   -2.01e-05    6.96e-06
# Q_1            0.1284      0.256      0.502      0.616      -0.374       0.631
# Q_2           -0.2834      0.230     -1.233      0.218      -0.735       0.168
# Q_3           -0.1156      0.231     -0.500      0.618      -0.571       0.339
# ==============================================================================
# Omnibus:                       55.528   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              380.621
# Skew:                           0.313   Prob(JB):                     2.23e-83
# Kurtosis:                       7.787   Cond. No.                     1.82e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.82e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      9   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.6506
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.661
# Time:                        13:01:30   Log-Likelihood:                -677.20
# No. Observations:                 392   AIC:                             1366.
# Df Residuals:                     386   BIC:                             1390.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1161      0.178      0.652      0.515      -0.234       0.466
# 1              0.0004      0.002      0.241      0.809      -0.003       0.004
# 4          -2.145e-06   5.87e-06     -0.366      0.715   -1.37e-05    9.39e-06
# Q_1            0.1040      0.218      0.477      0.634      -0.325       0.533
# Q_2           -0.2562      0.196     -1.307      0.192      -0.642       0.129
# Q_3           -0.0396      0.197     -0.201      0.841      -0.428       0.349
# ==============================================================================
# Omnibus:                       44.357   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              269.892
# Skew:                           0.145   Prob(JB):                     2.48e-59
# Kurtosis:                       7.055   Cond. No.                     1.82e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.82e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     10   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                    0.1605
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.977
# Time:                        13:01:30   Log-Likelihood:                -643.13
# No. Observations:                 390   AIC:                             1298.
# Df Residuals:                     384   BIC:                             1322.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0563      0.165      0.342      0.733      -0.268       0.381
# 1              0.0004      0.002      0.249      0.803      -0.003       0.003
# 4           4.628e-07   5.43e-06      0.085      0.932   -1.02e-05    1.11e-05
# Q_1            0.0284      0.202      0.141      0.888      -0.368       0.425
# Q_2           -0.1148      0.182     -0.630      0.529      -0.473       0.243
# Q_3           -0.0843      0.183     -0.462      0.645      -0.443       0.275
# ==============================================================================
# Omnibus:                       88.874   Durbin-Watson:                   1.875
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              571.920
# Skew:                           0.781   Prob(JB):                    6.44e-125
# Kurtosis:                       8.723   Cond. No.                     1.82e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.82e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     11   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     1.390
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.227
# Time:                        13:01:30   Log-Likelihood:                -184.76
# No. Observations:                 372   AIC:                             381.5
# Df Residuals:                     366   BIC:                             405.0
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0404      0.053      0.764      0.445      -0.063       0.144
# 1              0.0008      0.000      1.539      0.125      -0.000       0.002
# 4            2.41e-06   1.76e-06      1.373      0.171   -1.04e-06    5.86e-06
# Q_1           -0.0715      0.066     -1.085      0.279      -0.201       0.058
# Q_2            0.0609      0.058      1.047      0.296      -0.053       0.175
# Q_3           -0.0452      0.058     -0.784      0.433      -0.159       0.068
# ==============================================================================
# Omnibus:                      174.969   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1451.715
# Skew:                           1.788   Prob(JB):                         0.00
# Kurtosis:                      11.993   Cond. No.                     1.73e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.73e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      5   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.5108
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.768
# Time:                        13:01:30   Log-Likelihood:                -1014.1
# No. Observations:                 392   AIC:                             2040.
# Df Residuals:                     386   BIC:                             2064.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0204      0.541      0.038      0.970      -1.043       1.084
# 2             -0.3263      1.171     -0.279      0.781      -2.629       1.977
# 4          -7.305e-06   8.57e-06     -0.852      0.395   -2.42e-05    9.55e-06
# Q_1            0.6127      0.526      1.165      0.245      -0.421       1.647
# Q_2           -0.2366      0.463     -0.511      0.610      -1.147       0.674
# Q_3            0.1369      0.466      0.294      0.769      -0.779       1.053
# ==============================================================================
# Omnibus:                       94.781   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2038.488
# Skew:                          -0.376   Prob(JB):                         0.00
# Kurtosis:                      14.146   Cond. No.                     3.11e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.11e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      6   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.8298
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.529
# Time:                        13:01:30   Log-Likelihood:                -895.69
# No. Observations:                 392   AIC:                             1803.
# Df Residuals:                     386   BIC:                             1827.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3532      0.400      0.883      0.378      -0.433       1.139
# 2             -0.0039      0.866     -0.005      0.996      -1.707       1.699
# 4          -9.185e-06   6.34e-06     -1.449      0.148   -2.16e-05    3.28e-06
# Q_1            0.2526      0.389      0.650      0.516      -0.512       1.017
# Q_2           -0.4167      0.342     -1.217      0.224      -1.090       0.257
# Q_3           -0.0084      0.344     -0.024      0.980      -0.686       0.669
# ==============================================================================
# Omnibus:                       79.203   Durbin-Watson:                   2.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1429.358
# Skew:                           0.150   Prob(JB):                    4.16e-311
# Kurtosis:                      12.350   Cond. No.                     3.11e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.11e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      7   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.8737
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.499
# Time:                        13:01:30   Log-Likelihood:                -810.22
# No. Observations:                 392   AIC:                             1632.
# Df Residuals:                     386   BIC:                             1656.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3577      0.322      1.113      0.267      -0.274       0.990
# 2             -0.0526      0.696     -0.076      0.940      -1.422       1.316
# 4          -7.346e-06    5.1e-06     -1.442      0.150   -1.74e-05    2.67e-06
# Q_1            0.0965      0.313      0.309      0.758      -0.518       0.711
# Q_2           -0.4214      0.275     -1.530      0.127      -0.963       0.120
# Q_3           -0.1281      0.277     -0.462      0.644      -0.673       0.417
# ==============================================================================
# Omnibus:                       87.053   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              744.742
# Skew:                           0.656   Prob(JB):                    1.91e-162
# Kurtosis:                       9.624   Cond. No.                     3.11e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.11e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      8   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.6653
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.650
# Time:                        13:01:30   Log-Likelihood:                -739.42
# No. Observations:                 392   AIC:                             1491.
# Df Residuals:                     386   BIC:                             1515.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2602      0.268      0.969      0.333      -0.268       0.788
# 2              0.1140      0.581      0.196      0.845      -1.029       1.257
# 4          -5.095e-06   4.25e-06     -1.198      0.232   -1.35e-05    3.27e-06
# Q_1            0.1104      0.261      0.423      0.672      -0.403       0.624
# Q_2           -0.2822      0.230     -1.228      0.220      -0.734       0.170
# Q_3           -0.1184      0.231     -0.512      0.609      -0.573       0.336
# ==============================================================================
# Omnibus:                       55.669   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              379.224
# Skew:                           0.319   Prob(JB):                     4.49e-83
# Kurtosis:                       7.776   Cond. No.                     3.11e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.11e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      9   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.6478
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.663
# Time:                        13:01:30   Log-Likelihood:                -677.21
# No. Observations:                 392   AIC:                             1366.
# Df Residuals:                     386   BIC:                             1390.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1367      0.229      0.597      0.551      -0.314       0.587
# 2              0.1046      0.496      0.211      0.833      -0.871       1.080
# 4          -3.054e-06   3.63e-06     -0.841      0.401   -1.02e-05    4.08e-06
# Q_1            0.0991      0.223      0.445      0.656      -0.339       0.537
# Q_2           -0.2550      0.196     -1.300      0.194      -0.641       0.131
# Q_3           -0.0384      0.197     -0.195      0.846      -0.426       0.350
# ==============================================================================
# Omnibus:                       44.404   Durbin-Watson:                   1.896
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              269.656
# Skew:                           0.149   Prob(JB):                     2.79e-59
# Kurtosis:                       7.052   Cond. No.                     3.11e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.11e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     10   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                    0.1895
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.966
# Time:                        13:01:30   Log-Likelihood:                -643.06
# No. Observations:                 390   AIC:                             1298.
# Df Residuals:                     384   BIC:                             1322.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1091      0.212      0.515      0.607      -0.307       0.526
# 2              0.2085      0.459      0.455      0.650      -0.693       1.110
# 4          -1.608e-07   3.36e-06     -0.048      0.962   -6.76e-06    6.44e-06
# Q_1            0.0126      0.206      0.061      0.951      -0.392       0.417
# Q_2           -0.1124      0.182     -0.617      0.538      -0.471       0.246
# Q_3           -0.0838      0.182     -0.460      0.646      -0.442       0.275
# ==============================================================================
# Omnibus:                       88.569   Durbin-Watson:                   1.877
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              560.378
# Skew:                           0.783   Prob(JB):                    2.07e-122
# Kurtosis:                       8.660   Cond. No.                     3.11e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.11e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     11   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     2.063
# Date:                Tue, 07 May 2024   Prob (F-statistic):             0.0694
# Time:                        13:01:30   Log-Likelihood:                -183.09
# No. Observations:                 372   AIC:                             378.2
# Df Residuals:                     366   BIC:                             401.7
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1261      0.068      1.862      0.063      -0.007       0.259
# 2              0.3525      0.148      2.386      0.018       0.062       0.643
# 4           1.056e-06    1.1e-06      0.960      0.338   -1.11e-06    3.22e-06
# Q_1           -0.0959      0.067     -1.432      0.153      -0.227       0.036
# Q_2            0.0658      0.058      1.136      0.257      -0.048       0.180
# Q_3           -0.0439      0.057     -0.765      0.445      -0.157       0.069
# ==============================================================================
# Omnibus:                      173.995   Durbin-Watson:                   1.915
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1433.133
# Skew:                           1.778   Prob(JB):                         0.00
# Kurtosis:                      11.934   Cond. No.                     3.02e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.02e+05. This might indicate that there are
# ...
# No. Observations:                 392   AIC:                             2039.
# Df Residuals:                     386   BIC:                             2063.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1911      1.155      1.031      0.303      -1.081       3.463
# 3             -2.2536      2.276     -0.990      0.323      -6.729       2.222
# 4          -7.771e-06   8.23e-06     -0.944      0.346    -2.4e-05    8.42e-06
# Q_1            0.6602      0.518      1.275      0.203      -0.358       1.678
# Q_2           -0.1924      0.464     -0.414      0.679      -1.105       0.720
# Q_3            0.1592      0.466      0.342      0.733      -0.757       1.075
# ==============================================================================
# Omnibus:                       95.131   Durbin-Watson:                   2.030
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2021.204
# Skew:                          -0.388   Prob(JB):                         0.00
# Kurtosis:                      14.097   Cond. No.                     6.34e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      6   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.8300
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.529
# Time:                        13:01:30   Log-Likelihood:                -895.69
# No. Observations:                 392   AIC:                             1803.
# Df Residuals:                     386   BIC:                             1827.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3814      0.855      0.446      0.656      -1.300       2.063
# 3             -0.0568      1.685     -0.034      0.973      -3.370       3.256
# 4          -9.206e-06   6.09e-06     -1.511      0.132   -2.12e-05    2.78e-06
# Q_1            0.2542      0.383      0.663      0.507      -0.499       1.008
# Q_2           -0.4156      0.344     -1.209      0.227      -1.091       0.260
# Q_3           -0.0078      0.345     -0.023      0.982      -0.686       0.670
# ==============================================================================
# Omnibus:                       79.185   Durbin-Watson:                   2.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1428.833
# Skew:                           0.149   Prob(JB):                    5.41e-311
# Kurtosis:                      12.348   Cond. No.                     6.34e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      7   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9711
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.435
# Time:                        13:01:30   Log-Likelihood:                -809.97
# No. Observations:                 392   AIC:                             1632.
# Df Residuals:                     386   BIC:                             1656.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0753      0.687     -0.110      0.913      -1.426       1.276
# 3              0.9448      1.354      0.698      0.486      -1.717       3.607
# 4          -6.723e-06    4.9e-06     -1.373      0.171   -1.64e-05    2.91e-06
# Q_1            0.0571      0.308      0.185      0.853      -0.548       0.663
# Q_2           -0.4379      0.276     -1.586      0.114      -0.981       0.105
# Q_3           -0.1387      0.277     -0.500      0.617      -0.684       0.406
# ==============================================================================
# Omnibus:                       87.259   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              731.933
# Skew:                           0.665   Prob(JB):                    1.16e-159
# Kurtosis:                       9.561   Cond. No.                     6.34e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      8   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.7016
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.623
# Time:                        13:01:30   Log-Likelihood:                -739.33
# No. Observations:                 392   AIC:                             1491.
# Df Residuals:                     386   BIC:                             1514.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0260      0.574     -0.045      0.964      -1.154       1.102
# 3              0.5289      1.131      0.468      0.640      -1.694       2.752
# 4          -5.071e-06   4.09e-06     -1.240      0.216   -1.31e-05    2.97e-06
# Q_1            0.1031      0.257      0.401      0.689      -0.402       0.609
# Q_2           -0.2930      0.231     -1.271      0.205      -0.746       0.160
# Q_3           -0.1234      0.231     -0.533      0.594      -0.578       0.332
# ==============================================================================
# Omnibus:                       55.857   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              378.460
# Skew:                           0.325   Prob(JB):                     6.58e-83
# Kurtosis:                       7.770   Cond. No.                     6.34e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      9   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.7385
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.595
# Time:                        13:01:30   Log-Likelihood:                -676.98
# No. Observations:                 392   AIC:                             1366.
# Df Residuals:                     386   BIC:                             1390.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2174      0.490     -0.444      0.657      -1.180       0.745
# 3              0.6779      0.964      0.703      0.483      -1.218       2.574
# 4          -2.929e-06   3.49e-06     -0.839      0.402   -9.79e-06    3.93e-06
# Q_1            0.0855      0.219      0.390      0.697      -0.346       0.517
# Q_2           -0.2684      0.197     -1.365      0.173      -0.655       0.118
# Q_3           -0.0451      0.197     -0.228      0.820      -0.433       0.343
# ==============================================================================
# Omnibus:                       44.510   Durbin-Watson:                   1.895
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              267.589
# Skew:                           0.161   Prob(JB):                     7.83e-59
# Kurtosis:                       7.035   Cond. No.                     6.34e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     10   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2247
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.952
# Time:                        13:01:30   Log-Likelihood:                -642.97
# No. Observations:                 390   AIC:                             1298.
# Df Residuals:                     384   BIC:                             1322.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2170      0.453     -0.479      0.632      -1.108       0.674
# 3              0.5524      0.893      0.618      0.537      -1.204       2.309
# 4           -3.41e-07   3.23e-06     -0.106      0.916   -6.69e-06    6.01e-06
# Q_1            0.0143      0.203      0.070      0.944      -0.385       0.413
# Q_2           -0.1248      0.183     -0.682      0.495      -0.484       0.235
# Q_3           -0.0885      0.183     -0.485      0.628      -0.447       0.270
# ==============================================================================
# Omnibus:                       89.477   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              570.385
# Skew:                           0.791   Prob(JB):                    1.39e-124
# Kurtosis:                       8.710   Cond. No.                     6.34e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.34e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     11   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9929
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.422
# Time:                        13:01:30   Log-Likelihood:                -185.75
# No. Observations:                 372   AIC:                             383.5
# Df Residuals:                     366   BIC:                             407.0
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0684      0.146     -0.468      0.640      -0.356       0.219
# 3              0.1840      0.288      0.638      0.524      -0.383       0.751
# 4           3.419e-07   1.06e-06      0.321      0.748   -1.75e-06    2.44e-06
# Q_1           -0.0656      0.066     -0.988      0.324      -0.196       0.065
# Q_2            0.0578      0.059      0.987      0.325      -0.057       0.173
# Q_3           -0.0436      0.058     -0.753      0.452      -0.157       0.070
# ==============================================================================
# Omnibus:                      178.781   Durbin-Watson:                   1.891
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1527.416
# Skew:                           1.827   Prob(JB):                         0.00
# Kurtosis:                      12.230   Cond. No.                     6.13e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.13e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# {'weighted_slopes': shape: (7,)
# Series: 'total_df' [f64]
# [
# 	-0.026322
# 	-0.000798
# 	0.008307
# 	0.005171
# 	0.009057
# 	0.008221
# 	0.004432
# ], 'raw_slopes': shape: (7,)
# Series: 'total_df' [f64]
# [
# 	-0.008051
# 	-0.002117
# 	-0.000113
# 	-0.000422
# 	0.0004
# 	0.000383
# 	0.000756
# ], 'lm_slopes': shape: (7,)
# Series: 'total_df' [f64]
# [
# 	-0.326308
# 	-0.003934
# 	-0.052607
# 	0.114031
# 	0.104608
# 	0.208513
# 	0.352519
# ], 'harvard_slopes': shape: (7,)
# Series: 'total_df' [f64]
# [
# 	-2.25362
# 	-0.056819
# 	0.944824
# 	0.528853
# 	0.677927
# 	0.552354
# 	0.183957
# ]}

# %% [markdown]
# This loop iterate over slopes_dict where now each item is not a datafame but a series of values, where each series contain regression slopes for the whole data (data for different companies stacked in one dataframe) for each time frame of returns: 2-days, 3-days... 7_days, full quarter returns.

# %%
for slope in slopes_dict:
    print(f'{slope} for all data stacked displayed: \n {slopes_dict[slope]}')
    print("\n")
# Out:
# weighted_slopes for all data stacked displayed:
#  shape: (7,)
# Series: 'total_df' [f64]
# [
# 	-0.026322
# 	-0.000798
# 	0.008307
# 	0.005171
# 	0.009057
# 	0.008221
# 	0.004432
# ]
#
#
# raw_slopes for all data stacked displayed:
#  shape: (7,)
# Series: 'total_df' [f64]
# [
# 	-0.008051
# 	-0.002117
# 	-0.000113
# 	-0.000422
# 	0.0004
# 	0.000383
# 	0.000756
# ]
#
#
# lm_slopes for all data stacked displayed:
#  shape: (7,)
# Series: 'total_df' [f64]
# [
# 	-0.326308
# 	-0.003934
# 	-0.052607
# 	0.114031
# 	0.104608
# 	0.208513
# 	0.352519
# ]
#
#
# harvard_slopes for all data stacked displayed:
#  shape: (7,)
# Series: 'total_df' [f64]
# [
# 	-2.25362
# 	-0.056819
# 	0.944824
# 	0.528853
# 	0.677927
# 	0.552354
# 	0.183957
# ]

# %% [markdown]
# jupyter nbconvert --to pdf Parsim-sec\src\Analysis\YFiin_excess_returns.ipynb
#
# jupyter nbconvert --to html Parsim-sec\src\Analysis\YFiin_excess_returns.ipynb
